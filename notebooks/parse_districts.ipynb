# %%
districts_geojson_path = "../data/0301100100_UNITATS_ADM_POLIGONS.json"

# %%
import json


with open(districts_geojson_path, 'r') as f:
    districts_geojson = json.load(f)

# %%
districts = []

# %%
output_path = "../data/districts.parquet"

# %%
from shapely.geometry import shape
import geopandas as gpd

for feature in districts_geojson.get('features', []):
        properties = feature.get('properties', {})
        
        if properties.get('TIPUS_UA') == 'DISTRICTE':
            
            district_name = properties.get('NOM')
            
            geometry = shape(feature.get('geometry'))
            
            districts.append({
                'district_name': district_name,
                'geometry': geometry
            })
            
if districts:
    gdf = gpd.GeoDataFrame(districts, geometry='geometry', crs="EPSG:4326")
    
    gdf.to_parquet(output_path, index=False)

# %%
districts
# Out:
# [{'district_name': 'Ciutat Vella',
#   'geometry': <POLYGON ((431733.736 4582441.816, 431645.093 4582532.381, 431557.512 458262...>},
#  {'district_name': 'Eixample',
#   'geometry': <POLYGON ((432033.184 4583665.032, 432033.186 4583665.24, 432020.186 4583678...>},
#  {'district_name': 'Sants-Montjuïc',
#   'geometry': <MULTIPOLYGON (((428773.911 4580873.742, 428692.437 4580957.142, 428676.088 ...>},
#  {'district_name': 'Les Corts',
#   'geometry': <POLYGON ((425054.67 4583672.56, 425047.22 4583673.98, 425042.54 4583673.36,...>},
#  {'district_name': 'Sarrià-Sant Gervasi',
#   'geometry': <MULTIPOLYGON (((422515.648 4587515.101, 422512.666 4587517.253, 422512.963 ...>},
#  {'district_name': 'Gràcia',
#   'geometry': <POLYGON ((427826.987 4586145.356, 427820.696 4586151.704, 427816.459 458616...>},
#  {'district_name': 'Horta-Guinardó',
#   'geometry': <POLYGON ((426501.867 4586067.12, 426500.791 4586058.202, 426528.888 4585983...>},
#  {'district_name': 'Nou Barris',
#   'geometry': <POLYGON ((429473.834 4588578.601, 429473.817 4588574.556, 429474.644 458856...>},
#  {'district_name': 'Sant Andreu',
#   'geometry': <POLYGON ((432158.516 4590377.238, 432142.038 4590373.149, 432140.186 459037...>},
#  {'district_name': 'Sant Martí',
#   'geometry': <POLYGON ((433770.023 4586475.362, 433726.353 4586503.473, 433742.098 458652...>}]
